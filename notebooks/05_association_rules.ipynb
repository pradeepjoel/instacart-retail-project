# %% [markdown]
# # Association rule mining

# %% [markdown]
# ## 1️⃣ Load Parquet Files

# %%
import pandas as pd
import os
# notebook is in: project_root/notebooks
PROJECT_ROOT = os.path.abspath("..")

INTERIM_DIR = os.path.join(PROJECT_ROOT, "data", "interim")
PROCESSED_DIR = os.path.join(PROJECT_ROOT, "data", "processed")

op_train = pd.read_parquet(os.path.join(PROCESSED_DIR, "op_train_temporal.parquet"))
op_test  = pd.read_parquet(os.path.join(PROCESSED_DIR, "op_test_temporal.parquet"))

print(op_train.shape, op_test.shape)
# Out:
# (32434489, 4) (1384617, 4)

# %% [markdown]
# ### 2️⃣ Prepare Transactions

# %%
train_transactions = op_train.groupby("order_id")["product_id"].apply(list)
test_transactions  = op_test.groupby("order_id")["product_id"].apply(list)

train_transactions.head()
# Out:
# order_id
# 2    [33120, 28985, 9327, 45918, 30035, 17794, 4014...
# 3    [33754, 24838, 17704, 21903, 17668, 46667, 174...
# 4    [46842, 26434, 39758, 27761, 10054, 21351, 225...
# 5    [13176, 15005, 47329, 27966, 23909, 48370, 132...
# 6                                [40462, 15873, 41897]
# Name: product_id, dtype: object

# %% [markdown]
# ## 3️⃣ Convert to One-Hot Encoding (Needed for Apriori & FP-Growth)
# We will use `mlxtend` for this encoding, we can install `pip install mlxtend`.

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_array = te.fit(train_transactions).transform(train_transactions)

df_train_encoded = pd.DataFrame(te_array, columns=te.columns_)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 from mlxtend.preprocessing import TransactionEncoder
#       3 te = TransactionEncoder()
# ----> 4 te_array = te.fit(train_transactions).transform(train_transactions)
#       6 df_train_encoded = pd.DataFrame(te_array, columns=te.columns_)
#
# File c:\Users\i025423\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\i025423\AppData\Local\Programs\Python\Python314\Lib\site-packages\mlxtend\preprocessing\transactionencoder.py:126, in TransactionEncoder.transform(self, X, sparse)
#     124     array = csr_matrix((non_sparse_values, indices, indptr), dtype=bool)
#     125 else:
# --> 126     array = np.zeros((len(X), len(self.columns_)), dtype=bool)
#     127     for row_idx, transaction in enumerate(X):
#     128         for item in transaction:
#
# MemoryError: Unable to allocate 149. GiB for an array with shape (3214874, 49677) and data type bool

# %%
#basket_sizes = transactions_df["items"].apply(len)
#basket_sizes.describe(percentiles=[0.5, 0.75, 0.9, 0.95])

# %%
item_counter = Counter()

for items in transactions_df["items"]:
    item_counter.update(set(items))

item_freq_df = (
    pd.DataFrame(item_counter.items(), columns=["item", "count"])
    .sort_values("count", ascending=False)
    .reset_index(drop=True)
)

item_freq_df.head(15)
# Out:
#                       item   count
# 0                   Banana  473023
# 1   Bag of Organic Bananas  376928
# 2     Organic Strawberries  267943
# 3     Organic Baby Spinach  244707
# 4     Organic Hass Avocado  216041
# 5          Organic Avocado  180406
# 6              Large Lemon  157288
# 7                    Limes  143889
# 8             Strawberries  142586
# 9      Organic Raspberries  139544
# 10      Organic Whole Milk  137331
# 11    Organic Yellow Onion  115984
# 12          Organic Garlic  112456
# 13        Organic Zucchini  107884
# 14     Organic Blueberries  100748

# %%
pair_counter = Counter()

for items in transactions_df["items"]:
    unique_items = sorted(set(items))
    for pair in combinations(unique_items, 2):
        pair_counter[pair] += 1

pair_freq_df = (
    pd.DataFrame(pair_counter.items(), columns=["item_pair", "count"])
    .sort_values("count", ascending=False)
    .reset_index(drop=True)
)

pair_freq_df.head(10)
# Out:
#                                         item_pair  count
# 0  (Bag of Organic Bananas, Organic Hass Avocado)  64524
# 1  (Bag of Organic Bananas, Organic Strawberries)  64401
# 2                  (Banana, Organic Strawberries)  58147
# 3                       (Banana, Organic Avocado)  55442
# 4                  (Banana, Organic Baby Spinach)  53271
# 5  (Bag of Organic Bananas, Organic Baby Spinach)  52343
# 6                          (Banana, Strawberries)  43010
# 7                           (Banana, Large Lemon)  42915
# 8    (Organic Hass Avocado, Organic Strawberries)  42207
# 9   (Bag of Organic Bananas, Organic Raspberries)  42127

# %%
num_transactions = len(transactions_df)

# Map item -> count
item_count_map = dict(item_freq_df[["item", "count"]].values)

rules = []

for (item_a, item_b), pair_count in pair_counter.items():
    support = pair_count / num_transactions

    confidence_a_to_b = pair_count / item_count_map[item_a]
    confidence_b_to_a = pair_count / item_count_map[item_b]

    lift = support / (
        (item_count_map[item_a] / num_transactions) *
        (item_count_map[item_b] / num_transactions)
    )

    rules.append({
        "antecedent": item_a,
        "consequent": item_b,
        "pair_count": pair_count,
        "support": support,
        "confidence": confidence_a_to_b,
        "lift": lift
    })

rules_df = pd.DataFrame(rules)
rules_df.sort_values("lift", ascending=False).head(10)
# Out:
#                                                antecedent  \
# 260458          Unsweetened Whole Milk Peach Greek Yogurt
# 41981   Oh My Yog! Organic Wild Quebec Blueberry Cream...
# 205226  Mighty 4 Kale, Strawberry, Amaranth & Greek Yo...
# 31938   Mighty 4 Purple Carrot Blackberry Quinoa & Gre...
# 96751   Fiber & Protein Organic Pears, Raspberries, Bu...
# 184102                  Organic Stage 2 Carrots Baby Food
# 12989                             Raspberry Essence Water
# 110404  Mighty 4 Kale, Strawberry, Amaranth & Greek Yo...
# 65503      Oh My Yog! Madagascar Vanilla Trilayer Yogyurt
# 46875      Oh My Yog! Madagascar Vanilla Trilayer Yogyurt
#
#                                                consequent  pair_count  \
# 260458           Unsweetened Whole Milk Strawberry Yogurt         985
# 41981   Oh My Yog! Pacific Coast Strawberry Trilayer Y...        1521
# 205226  Mighty 4 Sweet Potato, Blueberry, Millet & Gre...        1188
# 31938   Mighty 4 Sweet Potato, Blueberry, Millet & Gre...         948
# 96751   Organic Fiber & Protein Pear Blueberry & Spina...        1099
# 184102                             Sweet Potatoes Stage 2         835
# 12989                        Unsweetened Blackberry Water        1064
# 110404  Mighty 4 Purple Carrot Blackberry Quinoa & Gre...         755
# 65503   Oh My Yog! Organic Wild Quebec Blueberry Cream...        1008
# 46875   Oh My Yog! Pacific Coast Strawberry Trilayer Y...        1252
#
#          support  confidence        lift
# 260458  0.000371    0.496472  642.461856
# 41981   0.000574    0.661592  608.682772
# 205226  0.000448    0.529176  543.003126
# 31938   0.000358    0.480974  493.541807
# 96751   0.000414    0.493046  458.709260
# 184102  0.000315    0.359914  452.927509
# 12989   0.000401    0.522337  452.461898
# 110404  0.000285    0.336303  452.416802
# 65503   0.000380    0.385763  444.914843
# 46875   0.000472    0.479143  440.824462

# %%
filtered_rules_df = rules_df[
    (rules_df["support"] >= 0.001) &      # appears in at least 0.1% of orders
    (rules_df["confidence"] >= 0.3) &     # decent implication strength
    (rules_df["lift"] >= 1.5)             # real positive association
].sort_values("lift", ascending=False)

print("Filtered rules:", filtered_rules_df.shape)
filtered_rules_df.head(15)
# Out:
# Filtered rules: (20, 6)
#                                               antecedent  \
# 33030                       Almond Milk Blueberry Yogurt
# 71329  Organic Whole Milk Strawberry Beet Berry Yogur...
# 12392        Blueberry on the Bottom Nonfat Greek Yogurt
# 12426            Peach on the Bottom Nonfat Greek Yogurt
# 61967                          Fat Free Blueberry Yogurt
# 69396                         Fat Free Strawberry Yogurt
# 42278      Icelandic Style Skyr Blueberry Non-fat Yogurt
# 37181                Non Fat Acai & Mixed Berries Yogurt
# 18826           Nonfat Icelandic Style Strawberry Yogurt
# 44047      Icelandic Style Skyr Blueberry Non-fat Yogurt
# 60672                           Non Fat Raspberry Yogurt
# 20990  Total 2% Lowfat Greek Strained Yogurt With Blu...
# 20992  Total 2% Lowfat Greek Strained Yogurt With Blu...
# 12112   Total 2% Lowfat Greek Strained Yogurt with Peach
# 35021                                             Apples
#
#                                               consequent  pair_count  \
# 33030                      Almond Milk Strawberry Yogurt        2762
# 71329        Yotoddler Organic Pear Spinach Mango Yogurt        2875
# 12392       Strawberry on the Bottom Nonfat Greek Yogurt        2847
# 12426       Strawberry on the Bottom Nonfat Greek Yogurt        2751
# 61967                          Total 0% Raspberry Yogurt        2703
# 69396                          Total 0% Raspberry Yogurt        3108
# 42278                           Non Fat Raspberry Yogurt        7413
# 37181                           Non Fat Raspberry Yogurt        3257
# 18826                         Vanilla Skyr Nonfat Yogurt        3972
# 44047                         Vanilla Skyr Nonfat Yogurt        6803
# 60672                         Vanilla Skyr Nonfat Yogurt        5212
# 20990   Total 2% Lowfat Greek Strained Yogurt with Peach        6439
# 20992  Total 2% with Strawberry Lowfat Greek Strained...        9524
# 12112  Total 2% with Strawberry Lowfat Greek Strained...        8205
# 35021                                        Clementines        3898
#
#         support  confidence        lift
# 33030  0.001042    0.571961  260.131328
# 71329  0.001084    0.444771  191.199556
# 12392  0.001074    0.437394  149.261197
# 12426  0.001038    0.346168  118.130244
# 61967  0.001019    0.369464   78.876112
# 69396  0.001172    0.310211   66.226192
# 42278  0.002796    0.375513   59.376204
# 37181  0.001228    0.364685   57.664064
# 18826  0.001498    0.364437   51.863026
# 44047  0.002566    0.344613   49.041821
# 60672  0.001966    0.310812   44.231586
# 20990  0.002428    0.303999   39.613661
# 20992  0.003592    0.449648   39.100450
# 12112  0.003094    0.403234   35.064342
# 35021  0.001470    0.350508   33.881836

# %%
OUTPUT_DIR = os.path.join(PROJECT_ROOT, "outputs")
os.makedirs(OUTPUT_DIR, exist_ok=True)

filtered_rules_df.to_csv(
    os.path.join(OUTPUT_DIR, "association_rules_named.csv"),
    index=False
)

print("✅ Saved association_rules_named.csv")
# Out:
# ✅ Saved association_rules_named.csv
