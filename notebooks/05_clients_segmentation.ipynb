# %%
# !pip install pandas pyarrow fastparquet
# Out:
# Requirement already satisfied: pandas in c:\users\dasha\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: pyarrow in c:\users\dasha\anaconda3\lib\site-packages (21.0.0)
# Requirement already satisfied: fastparquet in c:\users\dasha\anaconda3\lib\site-packages (2025.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dasha\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dasha\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dasha\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dasha\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: cramjam>=2.3 in c:\users\dasha\anaconda3\lib\site-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in c:\users\dasha\anaconda3\lib\site-packages (from fastparquet) (2025.10.0)
# Requirement already satisfied: packaging in c:\users\dasha\anaconda3\lib\site-packages (from fastparquet) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\dasha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime
import os

# %%
folder = Path(r"C:/Users/Dasha/Documents/project ML/enriched_data") 
files = list(folder.glob("part-*.parquet"))

df = pd.concat([pd.read_parquet(f) for f in files], ignore_index=True)


df = df.astype({
    "department": "str",
    "product_id": "int",
    "order_id": "int",
    "add_to_cart_order": "int",
    "reordered": "int",
    "department_id": "int",
    "aisle_id": "int", 
    "product_name": "str", 
    "avg_price": "int"    
})

df.head()
# Out:
#   department  product_id  order_id  add_to_cart_order  reordered  \
# 0     pantry       30064    188723                  2          0
# 1    produce       38557    124150                  9          0
# 2    produce       13176    539689                  2          1
# 3     babies        2611    544204                  1          1
# 4     pantry       18441      4707                  1          0
#
#    department_id  aisle_id                           product_name  \
# 0             13        17            Double Acting Baking Powder
# 1              4        24               Citrus Mandarins Organic
# 2              4        24                 Bag of Organic Bananas
# 3             18        92  Gluten Free SpongeBob Spinach Littles
# 4             13        72                        Organic Ketchup
#
#                 aisle  avg_price
# 0  baking ingredients          2
# 1        fresh fruits          1
# 2        fresh fruits          1
# 3   baby food formula          2
# 4          condiments          2

# %%
base_path = r"C:/Users/Dasha/Documents/project ML/raw_data"

orders = pd.read_csv(os.path.join(base_path, "orders.csv"))
# order_products = pd.read_csv(os.path.join(BASE_PATH, "order_products__prior.csv"))
# order_products_train = pd.read_csv(os.path.join(BASE_PATH, "order_products__train.csv"))
# products = pd.read_csv(os.path.join(BASE_PATH, "products.csv"))
# aisles = pd.read_csv(os.path.join(BASE_PATH, "aisles.csv"))
# departments = pd.read_csv(os.path.join(BASE_PATH, "departments.csv"))

# %%
# calculating the metrics

df_joined = df.merge(orders, on = "order_id", how = "left")
df_joined.head()

rfm_dataset = df_joined.groupby('user_id').agg({
    'days_since_prior_order': 'last', 
    'order_id': 'count', 
    'avg_price': 'sum'
}).rename(columns = {
    'days_since_prior_order': 'recency', 
    'order_id': 'frequency', 
    'avg_price': 'monetary'
})

rfm_dataset.head()
# Out:
#          recency  frequency  monetary
# user_id
# 1           19.0          7        13
# 2           13.0         14        24
# 3            7.0         10        17
# 4            NaN          1         3
# 5           10.0          4         4

# %%
r = pd.qcut(rfm_dataset['recency'].rank(method='first'), 
            q=5, 
            labels=range(5, 0, -1))

f = pd.qcut(rfm_dataset['frequency'], 
            q=5, 
            labels=range(1, 6),  
            duplicates='drop')

m = pd.qcut(rfm_dataset['monetary'], 
            q=5, 
            labels=range(1, 6),  # Fixed function name
            duplicates='drop')

rfm = rfm_dataset.assign(R=r.values, F=f.values, M=m.values)

# %%
# temporary solution for NaN values
rfm[['R', 'F', 'M']].isna().sum()
rfm[['R', 'F', 'M']] = rfm[['R', 'F', 'M']].fillna(1).astype(int)

# %%
rfm['rfm_group'] = rfm[['R', 'F', 'M']].apply(lambda v:'-'.join(v.astype(str)), axis = 1)
rfm['rfm_score_total'] = rfm[['R', 'F', 'M']].sum(axis=1)

# %%
rfm.sort_values(by='rfm_score_total', ascending=False).head()
# Out:
#          recency  frequency  monetary  R  F  M rfm_group  rfm_score_total
# user_id
# 135347       1.0         34        53  5  5  5     5-5-5               15
# 25926        4.0         91       160  5  5  5     5-5-5               15
# 50           5.0         55        77  5  5  5     5-5-5               15
# 25937        4.0         27        49  5  5  5     5-5-5               15
# 55768        3.0         33        49  5  5  5     5-5-5               15
